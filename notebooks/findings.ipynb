# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt

# %%
x = [5, 10, 100, 300, 550]
y = [0.0088459313, 0.0096895, 0.0023139, 0.00118106, 0.00062668]

plt.plot(x, y)
# x1,x2,y1,y2 = plt.axis()  
plt.yscale("log")
plt.axis((0,1100,0.0001, 0.1))
plt.show()
